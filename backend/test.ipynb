# %%
import pandas as pd

# %%
data = pd.read_csv("jobs.csv")

# %%
data[data["site"]=="google"].head(3)
# Out:
#                             id    site  \
# 0  go-FQw3PzlL2_ITjX5YAAAAAA==  google
# 1  go-9ED9eyWM8fIJgfC4AAAAAA==  google
# 2  go-JtYE78ASr6L0X02bAAAAAA==  google
#
#                                              job_url job_url_direct  \
# 0  https://www.inspyrsolutions.com/job/24-10946-s...            NaN
# 1  https://www.linkedin.com/jobs/view/senior-fron...            NaN
# 2  https://www.linkedin.com/jobs/view/software-de...            NaN
#
#                               title           company           location  \
# 0                Software Developer  INSPYR Solutions  San Francisco, CA
# 1  Senior Frontend Engineer (React)              Zywa  San Francisco, CA
# 2              Software Developer 2            Oracle  San Francisco, CA
#
#   date_posted  job_type salary_source  ... emails  \
# 0  2025-02-23  contract   description  ...    NaN
# 1  2025-02-22       NaN           NaN  ...    NaN
# 2  2025-02-21       NaN   description  ...    NaN
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'site', 'job_url', 'job_url_direct', 'title', 'company',
#        'location', 'date_posted', 'job_type', 'salary_source', 'interval',
#        'min_amount', 'max_amount', 'currency', 'is_remote', 'job_level',
#        'job_function', 'listing_type', 'emails', 'description',
#        'company_industry', 'company_url', 'company_logo', 'company_url_direct',
#        'company_addresses', 'company_num_employees', 'company_revenue',
#        'company_description'],
#       dtype='object')

# %%
data.shape
# Out:
# (60, 28)

# %%
data[data["site"]=="linkedin"].head(3)
# Out:
#                id      site                                        job_url  \
# 40  li-4151584188  linkedin  https://www.linkedin.com/jobs/view/4151584188
# 41  li-4168185593  linkedin  https://www.linkedin.com/jobs/view/4168185593
# 42  li-4143949417  linkedin  https://www.linkedin.com/jobs/view/4143949417
#
#    job_url_direct              title   company           location date_posted  \
# 40            NaN  Software Engineer  Greylock  San Francisco, CA  2025-03-01
# 41            NaN  Software Engineer    Twitch  San Francisco, CA  2025-02-28
# 42            NaN        AI Engineer  LinkedIn      Sunnyvale, CA  2025-02-28
#
#    job_type salary_source  ... emails  description  company_industry  \
# 40      NaN           NaN  ...    NaN          NaN               NaN
# 41      NaN           NaN  ...    NaN          NaN               NaN
# 42      NaN           NaN  ...    NaN          NaN               NaN
#
#                                           company_url company_logo  \
# ...

# %%
data[data["site"]=="indeed"].head(3)
# Out:
#                      id    site  \
# 20  in-4c2470e8822535a7  indeed
# 21  in-e40169ded692c506  indeed
# 22  in-e50592ed5571d624  indeed
#
#                                               job_url  \
# 20  https://www.indeed.com/viewjob?jk=4c2470e88225...
# 21  https://www.indeed.com/viewjob?jk=e40169ded692...
# 22  https://www.indeed.com/viewjob?jk=e50592ed5571...
#
#                                        job_url_direct  \
# 20  https://careers.hingehealth.com/jobs/2019/job?...
# 21                        https://dsp.prng.co/WX_exwb
# 22  https://jobs.lever.co/agtonomy/52ce56e6-0678-4...
#
#                                            title       company  \
# 20                          Software Engineer II  Hinge Health
# 21  Staff Software Engineer, Futures (Front-End)        Intuit
# 22        Software Engineer, Robotics Generalist      Agtonomy
#
#                        location date_posted  job_type salary_source  ...  \
# ...
